# %% [markdown]
# <a href="https://colab.research.google.com/github/THansenite/Apophenia_Python/blob/master/GameScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4
# !pip install requests
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.18.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2018.11.29)

# %%
import bs4
import requests

#res = requests.get('https://dmyha.pucksystems2.com/game/game_sheet/22773017')
res = requests.get('https://dmyha.pucksystems2.com/game/show/22773017')
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)

pageContent = soup.find("div", {"class": "yieldPageContent"})
#finalScore
pageContent
#soup
# Out:
# <div class="yieldPageContent">
# <script type="text/javascript">
#     var pusher_channel;
#   </script>
# <div id="GameShowScoreboardSimple">
# <ul class="game_info_bar_v2">
# <li class="date">
#       Sun, Mar 10, 2019
#   </li>
# <li class="location"><a href="https://dmyha.pucksystems2.com/" target="_self"></a></li>
# <li class="status game_clock-info">
# <span>FINAL</span>
# </li>
# </ul>
# <div class="game-header ">
# <style>
#
#     .game-header .game-team-away-22773017 .team-logo {
#       background-image: url(https://cdn3.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_large_square.jpg);
#     }
#
#
#
#     .game-header .game-team-home-22773017 .team-logo {
#       background-image: url(https://cdn1.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_large_square.jpg);
#     }
#
#   </style>
# <a class="team-name" href="https://dmyha.pucksystems2.com/page/show/4503281-bandits?subseason=545898">Bandits</a>
# <a class="team-crest away game-team-away-22773017" href="https://dmyha.pucksystems2.com/page/show/4503281-bandits?subseason=545898">
# <div class="team-logo"></div>
# <div class="team-abbrev">Bandts</div>
# </a>
# <div class="game-header-center">
# <span class="scores">
# <span class="away">2</span>
# <span class="separator"> - </span>
# <span class="home">2</span>
# </span>
# <span class="status">Final</span>
# </div>
# <a class="team-crest home game-team-home-22773017" href="https://dmyha.pucksystems2.com/page/show/4444313-aggressive-goldfish?subseason=545898">
# <div class="team-logo"></div>
# <div class="team-abbrev">Gldfsh</div>
# </a>
# <a class="team-name" href="https://dmyha.pucksystems2.com/page/show/4444313-aggressive-goldfish?subseason=545898">Aggressive Goldfish</a>
# </div>
# <table class="stat_table line_score_v2 player_stats-list">
# <thead>
# <tr class="periods">
# <th class="team"></th>
# <th title="1st Period">1</th>
# <th title="2nd Period">2</th>
# <th title="3rd Period">3</th>
# <th class="total">T</th>
# </tr>
# </thead>
# <tbody>
# <tr class="box-score-border" id="lineScore-team-3951140">
# <td class="team">Bandits</td>
# <td class="pts_1">1</td>
# <td class="pts_2">1</td>
# <td class="pts_3">0</td>
# <td class="away_team_score final_score score-final">2</td>
# </tr>
# <tr class="box-score-border" id="lineScore-team-3891009">
# <td class="team">Aggressive Goldfish</td>
# <td class="pts_1">0</td>
# <td class="pts_2">0</td>
# <td class="pts_3">2</td>
# <td class="home_team_score final_score score-final">2</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div id="liveGameSimple">
# </div>
# <div class=" game_show_nextgen" id="GameShowContent">
# <div class="tab_menu">
# <ul class="tab_menu-list" id="rapidTabs">
# <li class="tab_menu-tab z7 loaded selected" id="tab_gs3_game_summary_new">
# <a href="#" onclick="select_tab('tab_gs3_game_summary_new', '/game/tab_gs3_game_summary_new/22773017', {}); return false;">
#           Box Score
#         </a>
# </li>
# <li class="tab_menu-tab z6 " id="tab_gs3_player_stats">
# <a href="#" onclick="select_tab('tab_gs3_player_stats', '/game/tab_gs3_player_stats/22773017', {}); return false;">
#           Player Stats
#         </a>
# </li>
# <li class="tab_menu-tab z5 " id="tab_gs3_game_stats">
# <a href="#" onclick="select_tab('tab_gs3_game_stats', '/game/tab_gs3_game_stats/22773017', {}); return false;">
#           Team Stats
#         </a>
# </li>
# <li class="tab_menu-tab z4 " id="tab_gs3_play_by_play">
# <a href="#" onclick="select_tab('tab_gs3_play_by_play', '/game/tab_gs3_play_by_play/22773017', {}); return false;">
#           Play By Play
#         </a>
# </li>
# <li class="tab_menu-tab z3 " id="tab_gs3_photos">
# <a href="#" onclick="select_tab('tab_gs3_photos', '/game/tab_gs3_photos/22773017', {}); return false;">
#           Photos
#         </a>
# </li>
# <li class="tab_menu-tab z2 " id="tab_gs3_videos">
# <a href="#" onclick="select_tab('tab_gs3_videos', '/game/tab_gs3_videos/22773017', {}); return false;">
#           Videos
#         </a>
# </li>
# <li class="tab_menu-tab z1 " id="tab_nextgen_comments">
# <a href="#" onclick="select_tab('tab_nextgen_comments', '/game/tab_nextgen_comments/22773017', {}); return false;">
#           Comments
#         </a>
# </li>
# </ul>
# <div class="live_game_sheet sport-tools"><ul><li><a href="https://dmyha.pucksystems2.com/game/game_sheet/22773017" target="_blank">Live Game Sheet</a></li></ul></div>
# </div>
# <div class="tab_menu-listLoader" id="contentTabsLoader" style="display: none;"><img src="/app_images/loaderBarUserMode.gif"/></div>
# <div class="rapidContentGeneral" id="tab_gs3_game_summary_new_content"> <div class="GameShowDataContainer game_boxscore">
# <div id="gameTotal">
# <h3>Game Totals</h3>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <table class="stat_table line_score_v2 player_stats-list">
# <thead>
# <tr class="periods">
# <th class="team">SCORING</th>
# <th title="1st Period">1</th>
# <th title="2nd Period">2</th>
# <th title="3rd Period">3</th>
# <th class="total">T</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even" id="lineScore-team-3951140">
# <td class="team">Bandits</td>
# <td class="pts_1">1</td>
# <td class="pts_2">1</td>
# <td class="pts_3">0</td>
# <td class="colgroup-edge away_team_score final_score">2</td>
# </tr>
# <tr class="odd" id="lineScore-team-3891009">
# <td class="team">Aggressive Goldfish</td>
# <td class="pts_1">0</td>
# <td class="pts_2">0</td>
# <td class="pts_3">2</td>
# <td class="colgroup-edge home_team_score final_score">2</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <table class="stat_table line_score_v2 player_stats-list">
# <thead>
# <tr class="periods">
# <th class="team" colspan="2">POWER PLAYS</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even">
# <td class="team">Bandits</td>
# <td>0 for 3 (0.0%)</td>
# </tr>
# <tr class="odd">
# <td class="team">Aggressive Goldfish</td>
# <td>0 for 1 (0.0%)</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <table class="stat_table line_score_v2 player_stats-list">
# <thead>
# <tr class="periods">
# <th class="team">SHOTS</th>
# <th class="score" title="1st Period">1</th>
# <th class="score" title="2nd Period">2</th>
# <th class="colgroup-edge,score" title="3rd Period">3</th>
# <th class="total">T</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even">
# <td class="team">Bandits</td>
# <td>7</td>
# <td>4</td>
# <td>4</td>
# <td>15</td>
# </tr>
# <tr class="odd">
# <td class="team">Aggressive Goldfish</td>
# <td>7</td>
# <td>4</td>
# <td>5</td>
# <td>16</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <table class="stat_table line_score_v2 player_stats-list">
# <thead>
# <tr class="periods">
# <th class="team" colspan="2">PENALTIES</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even">
# <td class="team">Bandits</td>
# <td>2 minutes  on 1 infraction</td>
# </tr>
# <tr class="odd">
# <td class="team">Aggressive Goldfish</td>
# <td>6 minutes  on 3 infractions</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <h3>Scoring Summary</h3>
# <ul class="scoring_summary">
# <li class="interval_row">
# <ul>
# <li><span>1st</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# <li class="team_score">Bandts</li>
# <li class="team_score">Gldfsh</li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">14:56</li>
# <li class="team_name">Bandits</li>
# <li class="play_details">
#         #38 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584195?subseason=545898">Jordan Guy</a></span> (even strength) (#39 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584202?subseason=545898">Sean Curtis</a></span>)
#       </li>
# <li class="team_score">1</li>
# <li class="team_score">0</li>
# </ul>
# </li>
# <li class="interval_row">
# <ul>
# <li><span>2nd</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# <li class="team_score">Bandts</li>
# <li class="team_score">Gldfsh</li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">15:10</li>
# <li class="team_name">Bandits</li>
# <li class="play_details">
#         #6 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584193?subseason=545898">Jackson Foreman</a></span> (even strength) (#4 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584189?subseason=545898">Becky Current</a></span>)
#       </li>
# <li class="team_score">2</li>
# <li class="team_score">0</li>
# </ul>
# </li>
# <li class="interval_row">
# <ul>
# <li><span>3rd</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# <li class="team_score">Bandts</li>
# <li class="team_score">Gldfsh</li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">16:50</li>
# <li class="team_name">Aggressive Goldfish</li>
# <li class="play_details">
#         #17 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584527?subseason=545898">Tyler Shelton</a></span> (even strength) (#39 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584519?subseason=545898">Lee Collins</a></span>)
#       </li>
# <li class="team_score">2</li>
# <li class="team_score">1</li>
# </ul>
# </li>
# <li class="scoring_info odd">
# <ul>
# <li class="game_clock">17:22</li>
# <li class="team_name">Aggressive Goldfish</li>
# <li class="play_details">
#         #39 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584519?subseason=545898">Lee Collins</a></span> (even strength) (#16 <span class="playerLink"><a href="https://dmyha.pucksystems2.com/roster_players/27584523?subseason=545898">Paul Smith</a></span>)
#       </li>
# <li class="team_score">2</li>
# <li class="team_score">2</li>
# </ul>
# </li>
# </ul>
# <h3>Penalty Summary</h3>
# <ul class="scoring_summary">
# <li class="interval_row">
# <ul>
# <li><span>1st</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# <li class="team_score"></li>
# <li class="team_score"></li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="play_details">NO PENALTY</li>
# </ul>
# </li>
# <li class="interval_row">
# <ul>
# <li><span>2nd</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">1:51</li>
# <li class="team_name">Aggressive Goldfish</li>
# <li class="play_details"><span class="playerLink">
#               #13 <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584515">Chad Hepperly</a> Roughing - Minor (2:00)</span></li>
# </ul>
# </li>
# <li class="scoring_info odd">
# <ul>
# <li class="game_clock">5:26</li>
# <li class="team_name">Bandits</li>
# <li class="play_details"><span class="playerLink">
#               #11 <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584201">Scott Crowther</a> Tripping - Minor (2:00)</span></li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">9:31</li>
# <li class="team_name">Aggressive Goldfish</li>
# <li class="play_details"><span class="playerLink">
#               #7 <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584525">Tami Peiffer</a> Hooking - Minor (2:00)</span></li>
# </ul>
# </li>
# <li class="interval_row">
# <ul>
# <li><span>3rd</span> Period</li>
# <li class="game_clock"></li>
# <li class="team_name"></li>
# <li class="play_details"></li>
# </ul>
# </li>
# <li class="scoring_info even">
# <ul>
# <li class="game_clock">17:35</li>
# <li class="team_name">Aggressive Goldfish</li>
# <li class="play_details"><span class="playerLink">
#               #2 <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584521">Michael Stroinski</a> Hooking - Minor (2:00)</span></li>
# </ul>
# </li>
# </ul>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <h3 class="teamHeadline" style="border-color: #E01D54;">
# <span class="team_logo">
# <a class="teamLogo-tiny " href="https://dmyha.pucksystems2.com/page/show/4503281-bandits?subseason=545898" style="background-image:url(https://cdn1.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_tiny.jpg);" target="_top" title="Bandits"></a>
# </span>
#   Bandits Skaters
# </h3>
# <table class="player_stats-list stat_table" id="player-sm-3951140-table">
# <thead>
# <tr>
# <th title="Jersey Number">#</th>
# <th class="player_name" title="Player Name">Name</th>
# <th title="Goals">G</th>
# <th title="Assists">A</th>
# <th title="Points">PTS</th>
# <th title="Shots on Goal">SOG</th>
# <th title="Penalty Minutes">PIM</th>
# <th title="Plus / Minus">+ / -</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="jersey_no">00</td>
# <td class="player_name " sorttable_customkey="JagersonMark">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584199" title="View Mark Jagerson's Player Profile">Mark Jagerson</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">2</td>
# <td class="player_name " sorttable_customkey="McIntyreChristopher">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584191" title="View Christopher McIntyre's Player Profile">Christopher McIntyre</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">4</td>
# <td class="player_name " sorttable_customkey="CurrentBecky">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584189" title="View Becky Current's Player Profile">Becky Current</a>
# </td>
# <td>0</td>
# <td>1</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">6</td>
# <td class="player_name " sorttable_customkey="ForemanJackson">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584193" title="View Jackson Foreman's Player Profile">Jackson Foreman</a>
# </td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">11</td>
# <td class="player_name " sorttable_customkey="CrowtherScott">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584201" title="View Scott Crowther's Player Profile">Scott Crowther</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">13</td>
# <td class="player_name " sorttable_customkey="FortneySimon">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584203" title="View Simon Fortney's Player Profile">Simon Fortney</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">17</td>
# <td class="player_name " sorttable_customkey="ReynoldsNicholas">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584200" title="View Nicholas Reynolds's Player Profile">Nicholas Reynolds</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">24</td>
# <td class="player_name " sorttable_customkey="FerrenAndrew">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/28980243" title="View Andrew Ferren's Player Profile">Andrew Ferren</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">38</td>
# <td class="player_name " sorttable_customkey="GuyJordan">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584195" title="View Jordan Guy's Player Profile">Jordan Guy</a>
# </td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">39</td>
# <td class="player_name " sorttable_customkey="CurtisSean">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584202" title="View Sean Curtis's Player Profile">Sean Curtis</a>
# </td>
# <td>0</td>
# <td>1</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">58</td>
# <td class="player_name " sorttable_customkey="HoffmanTommy">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27568226" title="View Tommy Hoffman's Player Profile">Tommy Hoffman</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">69</td>
# <td class="player_name " sorttable_customkey="FortnerJeffrey">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584194" title="View Jeffrey Fortner's Player Profile">Jeffrey Fortner</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">76</td>
# <td class="player_name " sorttable_customkey="BusbyKen">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584197" title="View Ken Busby's Player Profile">Ken Busby</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">79</td>
# <td class="player_name " sorttable_customkey="Hippen JrLarry">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584198" title="View Larry Hippen Jr's Player Profile">Larry Hippen Jr</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# </tbody>
# <thead>
# <tr class="even totals">
# <th></th>
# <th class="player_name">Totals</th>
# <th title="Goals">
#             2
#           </th>
# <th title="Assists">
#             2
#           </th>
# <th title="Points">
#             4
#           </th>
# <th title="Shots on Goal">
#             15
#           </th>
# <th title="Penalty Minutes">
#             2
#           </th>
# <th title="Plus / Minus">
# </th>
# </tr>
# </thead>
# </table>
# </div>
# </div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <h3 class="teamHeadline" style="border-color: #D66B0D;">
# <span class="team_logo">
# <a class="teamLogo-tiny " href="https://dmyha.pucksystems2.com/page/show/4444313-aggressive-goldfish?subseason=545898" style="background-image:url(https://cdn2.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_tiny.jpg);" target="_top" title="Aggressive Goldfish"></a>
# </span>
#   Aggressive Goldfish Skaters
# </h3>
# <table class="player_stats-list stat_table" id="player-sm-3891009-table">
# <thead>
# <tr>
# <th title="Jersey Number">#</th>
# <th class="player_name" title="Player Name">Name</th>
# <th title="Goals">G</th>
# <th title="Assists">A</th>
# <th title="Points">PTS</th>
# <th title="Shots on Goal">SOG</th>
# <th title="Penalty Minutes">PIM</th>
# <th title="Plus / Minus">+ / -</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="jersey_no">2</td>
# <td class="player_name " sorttable_customkey="StroinskiMichael">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584521" title="View Michael Stroinski's Player Profile">Michael Stroinski</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>3</td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">7</td>
# <td class="player_name " sorttable_customkey="PeifferTami">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584525" title="View Tami Peiffer's Player Profile">Tami Peiffer</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">13</td>
# <td class="player_name " sorttable_customkey="HepperlyChad">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584515" title="View Chad Hepperly's Player Profile">Chad Hepperly</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">16</td>
# <td class="player_name " sorttable_customkey="SmithPaul">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584523" title="View Paul Smith's Player Profile">Paul Smith</a>
# </td>
# <td>0</td>
# <td>1</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">17</td>
# <td class="player_name " sorttable_customkey="SheltonTyler">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584527" title="View Tyler Shelton's Player Profile">Tyler Shelton</a>
# </td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">18</td>
# <td class="player_name " sorttable_customkey="TilleyKevin">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584517" title="View Kevin Tilley's Player Profile">Kevin Tilley</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">37</td>
# <td class="player_name " sorttable_customkey="WigginsBrandon">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584514" title="View Brandon Wiggins's Player Profile">Brandon Wiggins</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">39</td>
# <td class="player_name " sorttable_customkey="CollinsLee">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584519" title="View Lee Collins's Player Profile">Lee Collins</a>
# </td>
# <td>1</td>
# <td>1</td>
# <td>2</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">45</td>
# <td class="player_name " sorttable_customkey="ButlerRyan">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584524" title="View Ryan Butler's Player Profile">Ryan Butler</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">55</td>
# <td class="player_name " sorttable_customkey="SechserJohn">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27394054" title="View John Sechser's Player Profile">John Sechser</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="odd">
# <td class="jersey_no">85</td>
# <td class="player_name " sorttable_customkey="RobinsonKris">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584518" title="View Kris Robinson's Player Profile">Kris Robinson</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="even">
# <td class="jersey_no">96</td>
# <td class="player_name " sorttable_customkey="AustgenJustin">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584516" title="View Justin Austgen's Player Profile">Justin Austgen</a>
# </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
# </tbody>
# <thead>
# <tr class="even totals">
# <th></th>
# <th class="player_name">Totals</th>
# <th title="Goals">
#             2
#           </th>
# <th title="Assists">
#             2
#           </th>
# <th title="Points">
#             4
#           </th>
# <th title="Shots on Goal">
#             16
#           </th>
# <th title="Penalty Minutes">
#             6
#           </th>
# <th title="Plus / Minus">
# </th>
# </tr>
# </thead>
# </table>
# </div>
# </div>
# <div class="clearAll"></div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <h3 class="teamHeadline" style="border-color: #E01D54;">
# <span class="team_logo">
# <a class="teamLogo-tiny " href="https://dmyha.pucksystems2.com/page/show/4503281-bandits?subseason=545898" style="background-image:url(https://cdn1.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_tiny.jpg);" target="_top" title="Bandits"></a>
# </span>
#   Bandits Goalies
# </h3>
# <table class="player_stats-list stat_table" id="player-sm-3951140-table">
# <thead>
# <tr>
# <th title="Jersey Number">#</th>
# <th class="player_name" title="Player Name">Name</th>
# <th title="Minutes">MIN</th>
# <th title="Shots on Goal">SOG</th>
# <th title="Saves">SV</th>
# <th title="Goals Against">GA</th>
# <th title="Save Percentage">SV %</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="jersey_no">01</td>
# <td class="player_name " sorttable_customkey=" FryeDan">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584192" title="View Dan  Frye's Player Profile">Dan  Frye</a>
# </td>
# <td>58:00</td>
# <td>16</td>
# <td>14</td>
# <td>2</td>
# <td>.875</td>
# </tr>
# </tbody>
# <thead>
# <tr class="even totals">
# <th></th>
# <th class="player_name">Totals</th>
# <th title="Minutes">
#             58:00
#           </th>
# <th title="Shots on Goal">
#             16
#           </th>
# <th title="Saves">
#             14
#           </th>
# <th title="Goals Against">
#             2
#           </th>
# <th title="Save Percentage">
#             .875
#           </th>
# </tr>
# </thead>
# </table>
# </div>
# </div>
# <div class="StatWidgetColumn width50">
# <div class="spacer">
# <h3 class="teamHeadline" style="border-color: #D66B0D;">
# <span class="team_logo">
# <a class="teamLogo-tiny " href="https://dmyha.pucksystems2.com/page/show/4444313-aggressive-goldfish?subseason=545898" style="background-image:url(https://cdn2.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_tiny.jpg);" target="_top" title="Aggressive Goldfish"></a>
# </span>
#   Aggressive Goldfish Goalies
# </h3>
# <table class="player_stats-list stat_table" id="player-sm-3891009-table">
# <thead>
# <tr>
# <th title="Jersey Number">#</th>
# <th class="player_name" title="Player Name">Name</th>
# <th title="Minutes">MIN</th>
# <th title="Shots on Goal">SOG</th>
# <th title="Saves">SV</th>
# <th title="Goals Against">GA</th>
# <th title="Save Percentage">SV %</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="jersey_no">35</td>
# <td class="player_name " sorttable_customkey="HarrisAaron">
# <a class="" href="https://dmyha.pucksystems2.com/roster_players/27584513" title="View Aaron Harris's Player Profile">Aaron Harris</a>
# </td>
# <td>58:00</td>
# <td>15</td>
# <td>13</td>
# <td>2</td>
# <td>.867</td>
# </tr>
# </tbody>
# <thead>
# <tr class="even totals">
# <th></th>
# <th class="player_name">Totals</th>
# <th title="Minutes">
#             58:00
#           </th>
# <th title="Shots on Goal">
#             15
#           </th>
# <th title="Saves">
#             13
#           </th>
# <th title="Goals Against">
#             2
#           </th>
# <th title="Save Percentage">
#             .867
#           </th>
# </tr>
# </thead>
# </table>
# </div>
# </div>
# <div class="clearAll"></div>
# </div>
# <div id="game_details">
# <div class="extra_game_details">
# <div class="pageElement">
# <h3 class="statModuleTitle">Game Details</h3>
# <ul class="gameXtras">
# <li><label>Venue:</label></li>
# </ul>
# </div>
# </div>
# <div class="list_officials">
# <div class="pageElement">
# <h3 class="statModuleTitle">Officials</h3>
# <ul class="gameXtras">
# <li>
# <label>Official:</label>
#       Tim Wermers
#     </li>
# <li>
# <label>Official:</label>
#       Scott Good
#     </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
# //<![CDATA[
#
#     $j(".extra_game_details li:even").addClass("even");
#     $j(".extra_game_details li:odd").addClass("odd");
#     $j(".list_officials li:even").addClass("even");
#     $j(".list_officials li:odd").addClass("odd");
#
# //]]>
# </script></div>
# <div class="rapidContentGeneral" id="tab_gs3_player_stats_content" style="display:none"></div>
# <div class="rapidContentGeneral" id="tab_gs3_game_stats_content" style="display:none"></div>
# <div class="rapidContentGeneral" id="tab_gs3_play_by_play_content" style="display:none"></div>
# <div class="rapidContentGeneral" id="tab_gs3_photos_content" style="display:none"></div>
# <div class="rapidContentGeneral" id="tab_gs3_videos_content" style="display:none"></div>
# <div class="rapidContentGeneral" id="tab_nextgen_comments_content" style="display:none"></div>
# </div>
# <style type="text/css">
#   #GameShowContent .awayTeam { background-color: #E01D54; color: #ffffff; border-color: #E01D54; }
#   #GameShowContent .homeTeam { background-color: #D66B0D; color: #ffffff; border-color: #D66B0D; }
#   .awayTeam { background-color: #E01D54; color: #ffffff; border-color: #E01D54; }
#   .homeTeam { background-color: #D66B0D; color: #ffffff; border-color: #D66B0D; }
#   .awayTeam svg { fill: #E01D54; }
#   .homeTeam svg { fill: #D66B0D; }
#   html.csstransforms3d body.hockeyish .play .homeTeam svg .action-icon,
#   html.csstransforms3d body.hockeyish .marker.homeTeam svg .badge {
#     fill: #8018E1;
#   }
#   .teamlogo.awayTeam { background: url(https://cdn1.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_tiny.jpg) no-repeat center center; }
#   .teamlogo.homeTeam { background: url(https://cdn2.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_tiny.jpg) no-repeat center center; }
#   tr.awayTeam td { background-color: #E01D54; color: #ffffff; }
#   tr.homeTeam td { background-color: #D66B0D; color: #ffffff; }
#
#     #PBP .playAway .playType {
#       background-color: #E01D54
#     }
#     #PBP .playHome .playType {
#       background-color: #D66B0D
#     }
#
#   /* Gradients */
#   .awayTeamFade {
#     background: -moz-linear-gradient(left, #E01D54 50%, rgba(0,0,0,0) 100%); /* FF3.6+ */
#     background: -webkit-gradient(linear, left top, right top, color-stop(50%,#E01D54), color-stop(100%,rgba(0,0,0,0)));' /* Chrome,Safari4+ */
#     background: -webkit-linear-gradient(left,#E01D54 50%,rgba(0,0,0,0) 100%); /* Chrome10+,Safari5.1+ */
#     background: -o-linear-gradient(left,#E01D54 50%,rgba(0,0,0,0) 100%); /* Opera11.10+ */
#     background: -ms-linear-gradient(left,#E01D54 50%,rgba(0,0,0,0) 100%); /* IE10+ */
#     background: linear-gradient(left,#E01D54 50%,rgba(0,0,0,0) 100%); /* W3C */
#   }
#   .homeTeamFade {
#     background: -moz-linear-gradient(right, #D66B0D 50%, rgba(0,0,0,0) 100%); /* FF3.6+ */
#     background: -webkit-gradient(linear, right top, left top, color-stop(50%,#D66B0D), color-stop(100%,rgba(0,0,0,0)));' /* Chrome,Safari4+ */
#     background: -webkit-linear-gradient(right,#D66B0D 50%,rgba(0,0,0,0) 100%); /* Chrome10+,Safari5.1+ */
#     background: -o-linear-gradient(right,#D66B0D 50%,rgba(0,0,0,0) 100%); /* Opera11.10+ */
#     background: -ms-linear-gradient(right,#D66B0D 50%,rgba(0,0,0,0) 100%); /* IE10+ */
#     background: linear-gradient(right,#D66B0D 50%,rgba(0,0,0,0) 100%); /* W3C */
#   }
# </style>
# </div>

# %%
scoringSummary = soup.find("table", {"class": "stat_table line_score_v2 player_stats-list"})
teams = scoringSummary.findAll("td", {"class": "team"})
awayTeam = teams[0].text
homeTeam = teams[1].text

goalSummary = scoringSummary.findAll("td", {"class": lambda L: L and L.startswith('pts')})

goalSummary
#scoringSummary

#print("Away Team: " + awayTeam)
#print("Home Team: " + homeTeam)
# Out:
# [<td class="pts_1">1</td>,
#  <td class="pts_2">1</td>,
#  <td class="pts_3">0</td>,
#  <td class="pts_1">0</td>,
#  <td class="pts_2">0</td>,
#  <td class="pts_3">2</td>]

# %%
finalScore = soup.find("div", {"class": "game-header-center"})

awayScore = finalScore.find("span", {"class": "away"}).text
homeScore = finalScore.find("span", {"class": "home"}).text

print("Away Score: " + awayScore)
print("Home Score: " + homeScore)
