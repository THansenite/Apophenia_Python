# %% [markdown]
# <a href="https://colab.research.google.com/github/THansenite/Apophenia_Python/blob/master/GameScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4
# !pip install requests
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.18.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2018.11.29)

# %%
import bs4
import requests

res = requests.get('https://dmyha.pucksystems2.com/game/game_sheet/22773017')
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)

# scheduleWeeks = soup.findAll("a", {"class": "game"})

soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"7b8dc0b815","applicationID":"16731","transactionName":"IQkMERZcXApQQRZXAA8DTQIFXlU5RltcVRU=","queueTime":0,"applicationTime":41,"agent":""}</script>
# <script>(window.NREUM||(NREUM={})).loader_config={xpid:"XAECQldVDwAB"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(16),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(17),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(v,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(19)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(19)(r ...
# <title>Bandits 2 at Aggressive Goldfish 2 (Final) | Ice Hockey Game Sheet</title>
# <style media="screen,print" type="text/css">
#     /* CSS Reset v1.0 | 20080212 */
#     html, body, div, span, applet, object, iframe,
#     h1, h2, h3, h4, h5, h6, p, blockquote, pre,
#     a, abbr, acronym, address, big, cite, code,
#     del, dfn, em, font, img, ins, kbd, q, s, samp,
#     small, strike, strong, sub, sup, tt, var,
#     b, u, i, center,
#     dl, dt, dd, ol, ul, li,
#     fieldset, form, label, legend,
#     table, caption, tbody, tfoot, thead, tr, th, td { margin: 0; padding: 0; border: 0; outline: 0; font-size: 100%; vertical-align: baseline; background: transparent; }
#     body { line-height: 1; }
#     ol, ul { list-style: none; }
#     blockquote, q { quotes: none; }
#     blockquote:before, blockquote:after,
#     q:before, q:after { content: ''; content: none; }
#
#     /* remember to define focus styles! */
#     :focus { outline: 0; }
#
#     /* remember to highlight inserts somehow! */
#     ins { text-decoration: none; }
#     del { text-decoration: line-through; }
#
#     /* tables still need 'cellspacing="0"' in the markup */
#     table { border-collapse: collapse; border-spacing: 0; }
#
#     /* Ice Hockey Printable Box Score */
#     body{ font-family:Verdana,Arial,Helvetica,sans-serif; font-size: 9px; width: 98%; margin: 0 1%; }
#     th, td{ padding: 2px; text-align: center; vertical-align: middle; }
#
#     /* League Header */
#     #league_header{ border-bottom: solid 1px #CCC; font-size: 14px; margin-top: 10px; padding-bottom: 10px; }
#
#     /* Game Header */
#     #game_header{ margin-top: 10px; width: 100%; }
#     #game_header .teamScore{ width: 16%; float: left; text-align: center; margin-bottom: 10px; }
#     #game_header .teamScore img{ width: 100px; margin-bottom: 5px; }
#     #game_header .teamScore h1{ font-size: 12px; font-weight: bold; margin-bottom: 5px; }
#     #game_header .teamScore h2{ font-size: 36px; font-weight: bold; }
#     #game_header #box_score{ float: left; margin: 0 4% 20px; width: 60%; }
#     #game_header #box_score tbody{ border: solid 1px #CCC; }
#     #game_header #box_score .score{ width: 70px; }
#     #game_header #box_score .home{ border-top: solid 1px #CCC; }
#     #game_header #box_score .final{ font-size: 14px; font-weight: bold; }
#     #game_header #box_score .teamName{ font-weight: bold; }
#     .teamName{ text-align: left; }
#     #game_header #box_score img, #game_header #box_score .teamLogo{ width: 50px; }
#
#     /* Links */
#     a{color:#666;}
#
#     /* Game Details */
#     #game_details{ border-top: solid 1px #CCC; clear: both; padding: 10px 0 0; }
#     #game_details li{ margin-bottom: 3px; }
#     #game_details label{ font-weight: bold; padding-right: 3px; }
#
#     /* Stat Sections */
#     .statSection{ clear: both; padding-top: 10px; }
#     .statSection h4{ margin-top: 10px; }
#     .statTable{ margin-top: 5px; }
#     .statTable th{ font-weight: bold; }
#     .statTable th, .statTable td{ border: solid 1px #CCC; }
#     .statTable th, .statTable td{ width: 10%; }
#     .statTable .eventDetail{ width: 30%; text-align: left; }
#     .statTable .number, .statTable .time{ width: 5%; }
#     .statTable .name{ text-align: left; width: 20%; }
#     .statTable .signature{ width: 40%;}
#     .statTable tr.coaches{ height: 25px;}
#     .statTable .totals{ font-weight: bold; }
#     .statTable .totals .label{ text-align: right; padding-right: 10px; }
#
#     /* Full Stat Tables */
#     .fullStatTables .statTable{ width: 100%; margin-bottom: 10px; }
#     .fullStatTables h3{ font-size: 12px; }
#
#     /* Split Stat Tables */
#     .splitStatTables h3{ font-size: 12px; font-weight: bold; margin-top: 4px; }
#     .splitStatTables .teamLogo{ height: 20px; float: left; margin-right: 5px; }
#     .splitStatTables .away{ width: 49%; float: left; }
#     .splitStatTables .home{ width: 49%; float: right; }
#     .splitStatTables .statTable{ width: 100%; }
#
#     /* Credit */
#     .credit{ clear: both; padding: 10px 0; text-decoration:none; }
#     .credit img{ display: block; margin-top: 3px; width: 125px; }
#   </style>
# </head>
# <body>
# <h3 id="league_header">
#     Central Iowa D-League
#     , Regular Season
#   </h3>
# <div id="game_header">
# <div class="teamScore">
# <img alt="Away Team Logo" class="away_team_logo" src="https://cdn3.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_print.jpg"/>
# <h1 id="away_team_name">Bandits</h1>
# <h2 id="away_team_score">2</h2>
# </div>
# <table id="box_score">
# <thead>
# <tr>
# <!-- <th title="Team" class="team">Team</th> -->
# <th colspan="2"></th>
# <th class="score" title="1st Period">1</th>
# <th class="score" title="2nd Period">2</th>
# <th class="colgroup-edge,score" title="3rd Period">3</th>
# <th class="colgroup-edge score-final" id="box_score_final_heading" title="Final Score">T</th>
# </tr>
# </thead>
# <tbody id="test">
# <tr class="away">
# <td class="teamLogo">
# <img alt="Away Team Logo" class="away_team_logo" src="https://cdn3.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_print.jpg"/>
# </td>
# <td class="teamName" id="score_away_team_name">Bandits</td>
# <td class="score">1</td>
# <td class="score">1</td>
# <td class="score">0</td>
# <td class="colgroup-edge score-final">2</td>
# </tr>
# <tr class="home">
# <td class="teamLogo">
# <img alt="Home Team Logo" class="home_team_logo" src="https://cdn4.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_print.jpg"/>
# </td>
# <td class="teamName" id="score_home_team_name">Aggressive Goldfish</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td class="colgroup-edge score-final">2</td>
# </tr>
# </tbody>
# </table>
# <div class="teamScore">
# <img alt="Home Team Logo" class="home_team_logo" src="https://cdn4.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_print.jpg"/>
# <h1 id="home_team_name">Aggressive Goldfish</h1>
# <h2 id="home_team_score">2</h2>
# </div>
# </div>
# <ul id="game_details">
# <li><a class="game_link_referrer" href="/game/show/22773017?referrer=4444284&amp;subseason=545898"><img alt="FINAL" src="/app_images/game_center/final.gif"/></a></li>
# <li><label>Date:</label><span id="game_date">Mar 10, 2019</span></li>
# <li><label>Time:</label><span id="game_time"> 3:30 PM CDT </span></li>
# <li><label>Location:</label><span id="game_location"></span></li>
# <li><label>Status:</label><span id="game_status">Final</span></li>
# <li><label>Official</label><span id="game_refs">Tim Wermers, Scott Good</span></li>
# </ul>
# <div class="statSection splitStatTables">
# <div class="away">
# <h3>Shots on Goal</h3>
# <table class="statTable">
# <thead>
# <tr>
# <th class="teamName">Team</th>
# <th>1</th>
# <th>2</th>
# <th>3</th>
# <th id="shots_total_heading">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="teamName" id="shots_away_team_name">Bandits</td>
# <td>7</td>
# <td>4</td>
# <td>4</td>
# <td>15</td>
# </tr>
# <tr>
# <td class="teamName" id="shots_home_team_name">Aggressive Goldfish</td>
# <td>7</td>
# <td>4</td>
# <td>5</td>
# <td>16</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="home">
# <h3>Power Plays</h3>
# <table class="statTable">
# <thead>
# <tr>
# <th class="teamName">Team</th>
# <th>PP</th>
# <th>PIM</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="teamName" id="pp_away_team_name">Bandits</td>
# <td><span id="pp_goals_away_team">0</span>-<span id="pp_chances_away_team">3</span></td>
# <td id="pp_pim_total_away_team">2</td>
# </tr>
# <tr>
# <td class="teamName" id="pp_home_team_name">Aggressive Goldfish</td>
# <td><span id="pp_goals_home_team">0</span>-<span id="pp_chances_home_team">1</span></td>
# <td id="pp_pim_total_home_team">6</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="statSection fullStatTables" id="period_summaries">
# <h3>
#             1st
#           Period Summary
#         </h3>
# <table class="statTable">
# <thead><tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail">Scoring Detail</th><th>Score</th></tr></thead>
# <tbody>
# <tr>
# <td class="time">14:56</td>
# <td class="teamName">
#                     Bandits
#                 </td>
# <td class="eventDetail ">
#                   Jordan Guy
#                   Goal (even strength)
#                   <br/>
# <em>Assists: Sean Curtis
#                     </em>
# </td>
# <td>
#                   Bandts 1 -
#                   Gldfsh 0
#                 </td>
# </tr>
# <tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail" colspan="2">Penalty Detail</th></tr>
# </tbody>
# </table>
# <h3>
#             2nd
#           Period Summary
#         </h3>
# <table class="statTable">
# <thead><tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail">Scoring Detail</th><th>Score</th></tr></thead>
# <tbody>
# <tr>
# <td class="time">15:10</td>
# <td class="teamName">
#                     Bandits
#                 </td>
# <td class="eventDetail ">
#                   Jackson Foreman
#                   Goal (even strength)
#                   <br/>
# <em>Assists: Becky Current
#                     </em>
# </td>
# <td>
#                   Bandts 2 -
#                   Gldfsh 0
#                 </td>
# </tr>
# <tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail" colspan="2">Penalty Detail</th></tr>
# <tr>
# <td class="time">1:51</td>
# <td class="teamName">
#                     Aggressive Goldfish
#                 </td>
# <td class="eventDetail " colspan="2">
#                   Chad Hepperly:
#                   Roughing - Minor (2:00)
#                 </td>
# </tr>
# <tr>
# <td class="time">5:26</td>
# <td class="teamName">
#                     Bandits
#                 </td>
# <td class="eventDetail " colspan="2">
#                   Scott Crowther:
#                   Tripping - Minor (2:00)
#                 </td>
# </tr>
# <tr>
# <td class="time">9:31</td>
# <td class="teamName">
#                     Aggressive Goldfish
#                 </td>
# <td class="eventDetail " colspan="2">
#                   Tami Peiffer:
#                   Hooking - Minor (2:00)
#                 </td>
# </tr>
# </tbody>
# </table>
# <h3>
#             3rd
#           Period Summary
#         </h3>
# <table class="statTable">
# <thead><tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail">Scoring Detail</th><th>Score</th></tr></thead>
# <tbody>
# <tr>
# <td class="time">16:50</td>
# <td class="teamName">
#                     Aggressive Goldfish
#                 </td>
# <td class="eventDetail ">
#                   Tyler Shelton
#                   Goal (even strength)
#                   <br/>
# <em>Assists: Lee Collins
#                     </em>
# </td>
# <td>
#                   Bandts 2 -
#                   Gldfsh 1
#                 </td>
# </tr>
# <tr>
# <td class="time">17:22</td>
# <td class="teamName">
#                     Aggressive Goldfish
#                 </td>
# <td class="eventDetail ">
#                   Lee Collins
#                   Goal (even strength)
#                   <br/>
# <em>Assists: Paul Smith
#                     </em>
# </td>
# <td>
#                   Bandts 2 -
#                   Gldfsh 2
#                 </td>
# </tr>
# <tr><th class="time">Time</th><th class="teamName">Team</th><th class="eventDetail" colspan="2">Penalty Detail</th></tr>
# <tr>
# <td class="time">17:35</td>
# <td class="teamName">
#                     Aggressive Goldfish
#                 </td>
# <td class="eventDetail " colspan="2">
#                   Michael Stroinski:
#                   Hooking - Minor (2:00)
#                 </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="statSection splitStatTables" id="player_stats" style="page-break-before:always;">
# <div class="away">
# <img alt="Away Team Logo" class="teamLogo away_team_logo" src="https://cdn3.sportngin.com/attachments/team/4bb9-110404006/Bandits_Hockey_print.jpg"/>
# <h3 id="player_stats_away_team_name">Bandits</h3>
# <h4>Skaters</h4>
# <table class="statTable">
# <thead>
# <!-- categories based on League Settings -->
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th>G</th>
# <th>A</th>
# <th>PIM</th>
# <th>GWG</th>
# </tr>
# </thead>
# <tbody id="player_stats_away_team_skaters">
# <tr>
# <td class="number">00</td>
# <td class="name ">Mark Jagerson</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">2</td>
# <td class="name ">Christopher McIntyre</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">4</td>
# <td class="name ">Becky Current</td>
# <td>0</td>
# <td>
#                 1
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">6</td>
# <td class="name ">Jackson Foreman</td>
# <td>1</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">11</td>
# <td class="name ">Scott Crowther</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">13</td>
# <td class="name ">Simon Fortney</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">17</td>
# <td class="name ">Nicholas Reynolds</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">24</td>
# <td class="name ">Andrew Ferren</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">38</td>
# <td class="name ">Jordan Guy</td>
# <td>1</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">39</td>
# <td class="name ">Sean Curtis</td>
# <td>0</td>
# <td>
#                 1
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">58</td>
# <td class="name ">Tommy Hoffman</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">69</td>
# <td class="name ">Jeffrey Fortner</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">76</td>
# <td class="name ">Ken Busby</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">79</td>
# <td class="name ">Larry Hippen Jr</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="totals" id="skater_stats_totals_away_team">
# <td class="label" colspan="2">Totals:</td>
# <td id="goals_total_away_team">2</td>
# <td id="assists_total_away_team">2</td>
# <td id="pim_total_away_team">2</td>
# <td id="gwg_total_away_team">0</td>
# </tr>
# </tbody>
# </table>
# <h4>Goalies</h4>
# <table class="statTable">
# <thead>
# <!-- categories based on League Settings -->
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th>Min</th>
# <th>Sh</th>
# <th>Sv</th>
# <th>Dec</th>
# </tr>
# </thead>
# <tbody id="player_stats_away_team_goalies">
# <tr>
# <td class="number">01</td>
# <td class="name ">Dan  Frye</td>
# <td>
#                 58:00
#               </td>
# <td>16</td>
# <td>
#                 14
#               </td>
# <td>
#                   TIE
#               </td>
# </tr>
# <tr class="totals" id="goalie_stats_totals_away_team">
# <td class="label" colspan="2">Totals:</td>
# <td id="goalie_min_total_away_team">
#           58:00</td>
# <td id="goalie_shots_total_away_team">16</td>
# <td id="goalie_saves_total_away_team">14</td>
# <td>0</td>
# </tr>
# </tbody>
# </table>
# <h4>Coaches</h4>
# <table class="statTable">
# <thead>
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th class="signature">Signature</th>
# </tr>
# </thead>
# <tbody id="away_team_coaches">
# </tbody></table>
# </div>
# <div class="home">
# <img alt="Home Team Logo" class="teamLogo home_team_logo" src="https://cdn4.sportngin.com/attachments/team/cd77-108956691/Aggressive_Goldfish_Logo_print.jpg"/>
# <h3 id="player_stats_home_team_name">Aggressive Goldfish</h3>
# <h4>Skaters</h4>
# <table class="statTable">
# <thead>
# <!-- categories based on League Settings -->
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th>G</th>
# <th>A</th>
# <th>PIM</th>
# <th>GWG</th>
# </tr>
# </thead>
# <tbody id="player_stats_away_team_skaters">
# <tr>
# <td class="number">2</td>
# <td class="name ">Michael Stroinski</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">7</td>
# <td class="name ">Tami Peiffer</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">13</td>
# <td class="name ">Chad Hepperly</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">16</td>
# <td class="name ">Paul Smith</td>
# <td>0</td>
# <td>
#                 1
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">17</td>
# <td class="name ">Tyler Shelton</td>
# <td>1</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">18</td>
# <td class="name ">Kevin Tilley</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">37</td>
# <td class="name ">Brandon Wiggins</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">39</td>
# <td class="name ">Lee Collins</td>
# <td>1</td>
# <td>
#                 1
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">45</td>
# <td class="name ">Ryan Butler</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">55</td>
# <td class="name ">John Sechser</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">85</td>
# <td class="name ">Kris Robinson</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td class="number">96</td>
# <td class="name ">Justin Austgen</td>
# <td>0</td>
# <td>
#                 0
#               </td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr class="totals" id="skater_stats_totals_home_team">
# <td class="label" colspan="2">Totals:</td>
# <td id="goals_total_home_team">2</td>
# <td id="assists_total_home_team">2</td>
# <td id="pim_total_home_team">6</td>
# <td id="gwg_total_home_team">0</td>
# </tr>
# </tbody>
# </table>
# <h4>Goalies</h4>
# <table class="statTable">
# <thead>
# <!-- categories based on League Settings -->
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th>Min</th>
# <th>Sh</th>
# <th>Sv</th>
# <th>Dec</th>
# </tr>
# </thead>
# <tbody id="player_stats_home_team_goalies">
# <tr>
# <td class="number">35</td>
# <td class="name ">Aaron Harris</td>
# <td>
#                 58:00
#               </td>
# <td>15</td>
# <td>
#                 13
#               </td>
# <td>
#                   TIE
#               </td>
# </tr>
# <tr class="totals" id="goalie_stats_totals_home_team">
# <td class="label" colspan="2">Totals:</td>
# <td id="goalie_min_total_home_team">
#           58:00</td>
# <td id="goalie_shots_total_home_team">15</td>
# <td id="goalie_saves_total_home_team">13</td>
# <td>0</td>
# </tr>
# </tbody>
# </table>
# <h4>Coaches</h4>
# <table class="statTable">
# <thead>
# <tr>
# <th class="number">#</th>
# <th class="name">Name</th>
# <th class="signature">Signature</th>
# </tr>
# </thead>
# <tbody id="home_team_coaches">
# </tbody></table>
# </div>
# </div>
# <div class="statSection" id="scoringSummary">
# <p>
#           1st Period -- Scoring: Bandts - Guy Goal (even strength)  (Curtis) 14:56. Penalties: None. Goalie Changes: None.
#         </p><br/>
# <p>
#           2nd Period -- Scoring: Bandts - Foreman Goal (even strength)  (Current) 15:10. Penalties: Hepperly, Gldfsh (Roughing, Minor, 2 min) 1:51; Crowther, Bandts (Tripping, Minor, 2 min) 5:26; Peiffer, Gldfsh (Hooking, Minor, 2 min) 9:31. Goalie Changes: None.
#         </p><br/>
# <p>
#           3rd Period -- Scoring: Gldfsh - Shelton Goal (even strength)  (Collins) 16:50; Gldfsh - Collins Goal (even strength)  (Smith) 17:22. Penalties: Stroinski, Gldfsh (Hooking, Minor, 2 min) 17:35. Goalie Changes: None.
#         </p><br/>
# </div>
# <div class="credit">
# <a href="https://sportngin.com/" title="Stats powered by SportsEngine, click to learn more">  Statistics Powered by <img id="ngin_logo" src="/logo_images/logo_381x70.png"/></a>
# </div>
# </body></html>
